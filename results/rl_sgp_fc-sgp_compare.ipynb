# %%
import pandas as pd

# %%
rl = pd.read_csv('rl_params_and_metrics.csv')
rl.drop(columns=['Unnamed: 0'], inplace=True)
rl.columns = ["image", "num_iters", "execution_time", "star_coord", "rel_recon_errors", "flux_before", "flux_after", "centroid_err", "l1_centroid_err", "l2_centroid_err", "before_ecc", "after_ecc", "before_fwhm (pix)", "after_fwhm (pix)", "flag"]

fcsgp = pd.read_csv('fc_sgp_params_and_metrics.csv')
fcsgp.drop(columns=['Unnamed: 0'], inplace=True)
fcsgp.columns = ["image", "num_iters", "execution_time", "DEFAULT_PARAMS", "star_coord", "rel_klds", "rel_recon_errors", "flux_before", "flux_after", "centroid_err", "l1_centroid_err", "l2_centroid_err", "before_ecc", "after_ecc", "before_fwhm (pix)", "after_fwhm (pix)", "flag"]

sgp = pd.read_csv('sgp_params_and_metrics.csv')
sgp.drop(columns=['Unnamed: 0'], inplace=True)
sgp.columns = ["image", "num_iters", "execution_time", "DEFAULT_PARAMS", "star_coord", "rel_klds", "rel_recon_errors", "flux_before", "flux_after", "centroid_err", "l1_centroid_err", "l2_centroid_err", "before_ecc", "after_ecc", "before_fwhm (pix)", "after_fwhm (pix)", "flag"]

# %%
rl
# Out:
#                 image  num_iters  execution_time            star_coord  \
# 0   ccfbue110099.fits          6           0.022  (327.3375, 106.8566)
# 1   ccfbvc170118.fits          2           0.006   (474.0155, 402.918)
# 2   ccfbvc170118.fits         11           0.023   (178.244, 506.4522)
# 3   ccfbvc170118.fits          9           0.018   (485.6476, 528.831)
# 4   ccfbvc170119.fits          2           0.005  (226.8246, 174.0645)
# 5   ccfbvc170119.fits         11           0.015  (515.4571, 110.0911)
# 6   ccfbvc170119.fits         11           0.019  (297.1877, 311.5624)
# 7   ccfbvc170120.fits          2           0.003  (484.9905, 435.0559)
# 8   ccfbvc170120.fits          8           0.013  (266.2868, 418.8551)
# 9   ccfbvc170121.fits         11           0.029  (178.0998, 506.4224)
# 10  ccfbvc170121.fits         11           0.018  (443.4051, 132.5788)
# 11  ccfbvc310078.fits         11           0.021   (178.0553, 506.567)
# ...

# %%
fcsgp
# Out:
#                 image  num_iters  execution_time  \
# 0   ccfbue110099.fits          3           0.017
# 1   ccfbvc170118.fits          3           0.008
# 2   ccfbvc170118.fits          3           0.011
# 3   ccfbvc170118.fits          3           0.012
# 4   ccfbvc170119.fits          3           0.008
# 5   ccfbvc170119.fits          2           0.009
# 6   ccfbvc170119.fits          2           0.008
# 7   ccfbvc170120.fits          3           0.009
# 8   ccfbvc170120.fits          3           0.008
# 9   ccfbvc170121.fits          3           0.012
# 10  ccfbvc170121.fits          3           0.011
# 11  ccfbvc310078.fits          2           0.008
# 12  ccfbvc310078.fits          2           0.009
# 13  ccfbvc310080.fits          2           0.007
# 14  ccfbvc310080.fits          3           0.007
# 15  ccfbvc310081.fits          7           0.014
# 16  ccfbvd120064.fits          2           0.006
# 17  ccfbvd120067.fits          4           0.010
# ...

# %%
sgp
# Out:
#                 image  num_iters  execution_time  \
# 0   ccfbue110099.fits          3           0.020
# 1   ccfbvc170118.fits          4           0.013
# 2   ccfbvc170118.fits          5           0.015
# 3   ccfbvc170118.fits          3           0.013
# 4   ccfbvc170119.fits          4           0.011
# 5   ccfbvc170119.fits          5           0.014
# 6   ccfbvc170119.fits          5           0.013
# 7   ccfbvc170120.fits          5           0.011
# 8   ccfbvc170120.fits          6           0.017
# 9   ccfbvc170121.fits          4           0.011
# 10  ccfbvc170121.fits          6           0.020
# 11  ccfbvc310078.fits          6           0.014
# 12  ccfbvc310078.fits          2           0.009
# 13  ccfbvc310080.fits          4           0.010
# 14  ccfbvc310080.fits          4           0.010
# 15  ccfbvc310081.fits          4           0.014
# 16  ccfbvd120064.fits          6           0.013
# 17  ccfbvd120067.fits          6           0.033
# ...

# %%
rl.columns, sgp.columns, fcsgp.columns
# Out:
# (Index(['image', 'num_iters', 'execution_time', 'star_coord',
#         'rel_recon_errors', 'flux_before', 'flux_after', 'centroid_err',
#         'l1_centroid_err', 'l2_centroid_err', 'before_ecc', 'after_ecc',
#         'before_fwhm (pix)', 'after_fwhm (pix)', 'flag'],
#        dtype='object'),
#  Index(['image', 'num_iters', 'execution_time', 'DEFAULT_PARAMS', 'star_coord',
#         'rel_klds', 'rel_recon_errors', 'flux_before', 'flux_after',
#         'centroid_err', 'l1_centroid_err', 'l2_centroid_err', 'before_ecc',
#         'after_ecc', 'before_fwhm (pix)', 'after_fwhm (pix)', 'flag'],
#        dtype='object'),
#  Index(['image', 'num_iters', 'execution_time', 'DEFAULT_PARAMS', 'star_coord',
#         'rel_klds', 'rel_recon_errors', 'flux_before', 'flux_after',
#         'centroid_err', 'l1_centroid_err', 'l2_centroid_err', 'before_ecc',
#         'after_ecc', 'before_fwhm (pix)', 'after_fwhm (pix)', 'flag'],
#        dtype='object'))
