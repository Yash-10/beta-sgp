# %%
import pandas as pd

# %%
# !ls -lh *csv
# Out:
# -rw-rw-r-- 1 oem oem  835 Jun 23 00:30 coords_to_use.csv
# -rw-rw-r-- 1 oem oem 4.4K Mar 23 00:37 fc_sgp_compare.csv
# -rw-rw-r-- 1 oem oem 6.1K Jun 28 11:55 fc_sgp_params_and_metrics.csv
# -rw-rw-r-- 1 oem oem  37K Jun 25 19:23 radprof_params_and_metrics.csv
# -rw-rw-r-- 1 oem oem 6.4K Jun 28 11:55 rl_params_and_metrics.csv
# -rw-rw-r-- 1 oem oem 7.4K Jun 28 11:54 sgp_params_and_metrics.csv
# -rw-rw-r-- 1 oem oem 249K Jun  3 17:25 standard_stars.csv

# %%
# !ls -lh *sgp_params_and_metrics*
# Out:
# -rw-rw-r-- 1 oem oem 6.1K Jun 28 11:55 fc_sgp_params_and_metrics.csv
# -rw-rw-r-- 1 oem oem 7.4K Jun 28 11:54 sgp_params_and_metrics.csv

# %%
df = pd.read_csv('fc_sgp_params_and_metrics.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.columns = ["image", "num_iters", "execution_time", "DEFAULT_PARAMS", "star_coord", "rel_klds", "rel_recon_errors", "flux_before", "flux_after", "centroid_err", "l1_centroid_err", "l2_centroid_err", "before_ecc", "after_ecc", "before_fwhm (pix)", "after_fwhm (pix)", "flag"]
df
# Out:
#                 image  num_iters  execution_time  \
# 0   ccfbue110099.fits          3           0.017
# 1   ccfbvc170118.fits          3           0.008
# 2   ccfbvc170118.fits          3           0.011
# 3   ccfbvc170118.fits          3           0.012
# 4   ccfbvc170119.fits          3           0.008
# 5   ccfbvc170119.fits          2           0.009
# 6   ccfbvc170119.fits          2           0.008
# 7   ccfbvc170120.fits          3           0.009
# 8   ccfbvc170120.fits          3           0.008
# 9   ccfbvc170121.fits          3           0.012
# 10  ccfbvc170121.fits          3           0.011
# 11  ccfbvc310078.fits          2           0.008
# 12  ccfbvc310078.fits          2           0.009
# 13  ccfbvc310080.fits          2           0.007
# 14  ccfbvc310080.fits          3           0.007
# 15  ccfbvc310081.fits          7           0.014
# 16  ccfbvd120064.fits          2           0.006
# 17  ccfbvd120067.fits          4           0.010
# 18  ccfbvf110066.fits          8           0.020
# 19  ccfbvf110069.fits          2           0.007
# 20  ccfbwd010113.fits          3           0.008
# 21  ccfbxb090103.fits          2           0.007
#
#                                        DEFAULT_PARAMS            star_coord  \
# 0   (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (327.3375, 106.8566)
# 1   (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...   (474.0155, 402.918)
# 2   (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...   (178.244, 506.4522)
# 3   (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...   (485.6476, 528.831)
# 4   (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (226.8246, 174.0645)
# 5   (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (515.4571, 110.0911)
# 6   (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (297.1877, 311.5624)
# 7   (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (484.9905, 435.0559)
# 8   (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (266.2868, 418.8551)
# 9   (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (178.0998, 506.4224)
# 10  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (443.4051, 132.5788)
# 11  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...   (178.0553, 506.567)
# 12  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (513.7465, 403.1672)
# 13  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...    (178.1496, 506.69)
# 14  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (297.1078, 311.5216)
# 15  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...   (393.0507, 312.993)
# 16  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...    (480.1201, 27.653)
# 17  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (430.7711, 436.9033)
# 18  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...    (430.91, 436.7877)
# 19  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (466.6864, 303.6346)
# 20  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (266.2741, 418.8532)
# 21  (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...  (327.2416, 106.9162)
#
#                                              rel_klds rel_recon_errors  \
# 0   [0.15634477045763842, 0.00019011775074820837, ...               []
# 1   [0.08007758479694331, 0.003037019057202272, 6....               []
# 2   [0.08604338291383358, 0.0018018105101716576, 2...               []
# 3   [0.08894840876865016, 0.0023281790198920716, 2...               []
# 4   [0.04893809127321742, 0.0003606065082920068, 0.0]               []
# 5       [0.08026263792816644, 2.5965690073190985e-15]               []
# 6                          [0.08190492902143579, 0.0]               []
# 7   [0.07792561384538257, 0.013538662946226132, 1....               []
# 8   [0.04745118029172015, 0.0016049956019242278, 6...               []
# 9   [0.03610456986986957, 0.00135307149247566, 6.8...               []
# 10  [0.08386165018537761, 0.00018429057029607725, ...               []
# 11      [0.027461766948917558, 1.013563855240287e-14]               []
# 19            0.869    0.274661   0.328068              9.964
# 20            0.758    0.514377   0.070246             13.286
# 21            0.541    0.136164   0.299899              8.781
#
#     after_fwhm (pix)  flag
# 0              3.514     1
# 1              4.859     1
# 2              3.557     1
# 3              4.237     1
# 4              5.622     1
# 5              5.783     1
# 6              5.632     1
# 7              3.879     1
# 8              5.187     1
# 9              5.748     1
# 10             6.807     1
# 11             5.803     1
# 12             9.711     1
# 13             4.166     1
# 14             3.884     1
# 15             3.980     1
# 16             5.690     1
# 17             5.252     1
# 18             4.506     1
# 19             5.207     1
# 20             2.447     1
# 21             4.208     1

# %%
df.iloc[5], df.iloc[9], df.iloc[4]
# Out:
# (image                                                ccfbvc170119.fits
#  num_iters                                                            2
#  execution_time                                                   0.009
#  DEFAULT_PARAMS       (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...
#  star_coord                                        (515.4571, 110.0911)
#  rel_klds                 [0.08026263792816644, 2.5965690073190985e-15]
#  rel_recon_errors                                                    []
#  flux_before                                                  78685.954
#  flux_after                                                   78438.959
#  centroid_err                                           [-0.146  1.075]
#  l1_centroid_err                                                  1.221
#  l2_centroid_err                                                  1.085
#  before_ecc                                                    0.095276
#  after_ecc                                                     0.175844
#  before_fwhm (pix)                                               10.991
#  after_fwhm (pix)                                                 5.783
#  flag                                                                 1
#  Name: 5, dtype: object,
#  image                                                ccfbvc170121.fits
#  num_iters                                                            3
#  execution_time                                                   0.012
#  DEFAULT_PARAMS       (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...
#  star_coord                                        (178.0998, 506.4224)
#  rel_klds             [0.03610456986986957, 0.00135307149247566, 6.8...
#  rel_recon_errors                                                    []
#  flux_before                                                  40462.343
#  flux_after                                                   40265.699
#  centroid_err                                             [0.088 0.702]
#  l1_centroid_err                                                   0.79
#  l2_centroid_err                                                  0.708
#  before_ecc                                                    0.026609
#  after_ecc                                                     0.123904
#  before_fwhm (pix)                                               11.372
#  after_fwhm (pix)                                                 5.748
#  flag                                                                 1
#  Name: 9, dtype: object,
#  image                                                ccfbvc170119.fits
#  num_iters                                                            3
#  execution_time                                                   0.008
#  DEFAULT_PARAMS       (1000, 0.0001, 0.4, 1e-05, 100000.0, 10.0, 3, ...
#  star_coord                                        (226.8246, 174.0645)
#  rel_klds             [0.04893809127321742, 0.0003606065082920068, 0.0]
#  rel_recon_errors                                                    []
#  flux_before                                                  11975.573
#  flux_after                                                   11925.938
#  centroid_err                                             [0.284 0.714]
#  l1_centroid_err                                                  0.998
#  l2_centroid_err                                                  0.769
#  before_ecc                                                    0.052189
#  after_ecc                                                      0.17704
#  before_fwhm (pix)                                               11.874
#  after_fwhm (pix)                                                 5.622
#  flag                                                                 1
#  Name: 4, dtype: object)
