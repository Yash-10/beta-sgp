# %%
import pandas as pd

# %%
# !ls -lh *csv
# Out:
# -rw-rw-r-- 1 oem oem  835 Jun 23 00:30 coords_to_use.csv
# -rw-rw-r-- 1 oem oem 5.7K Jun 29 15:41 fc_sgp_params_and_metrics.csv
# -rw-rw-r-- 1 oem oem  37K Jun 29 15:34 radprof_params_and_metrics.csv
# -rw-rw-r-- 1 oem oem 6.1K Jun 29 15:33 rl_params_and_metrics.csv
# -rw-rw-r-- 1 oem oem 4.9K Jun 29 15:33 sgp_params_and_metrics.csv
# -rw-rw-r-- 1 oem oem 249K Jun  3 17:25 standard_stars.csv

# %%
# !ls -lh *sgp_params_and_metrics*
# Out:
# -rw-rw-r-- 1 oem oem 5.7K Jun 29 15:41 fc_sgp_params_and_metrics.csv
# -rw-rw-r-- 1 oem oem 4.9K Jun 29 15:33 sgp_params_and_metrics.csv

# %%
ccfbvc170119.fits_297.1877_311.5624_SGP_orig.fits

# %%
df = pd.read_csv('fc_sgp_params_and_metrics.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#                 image  num_iters  execution_time            star_coord  \
# 0   ccfbue110099.fits          2           0.011  (327.3375, 106.8566)
# 1   ccfbvc170118.fits          2           0.009   (474.0155, 402.918)
# 2   ccfbvc170118.fits          2           0.006   (178.244, 506.4522)
# 3   ccfbvc170118.fits          2           0.006   (485.6476, 528.831)
# 4   ccfbvc170119.fits          2           0.007  (226.8246, 174.0645)
# 5   ccfbvc170119.fits          2           0.008  (515.4571, 110.0911)
# 6   ccfbvc170119.fits          2           0.009  (297.1877, 311.5624)
# 7   ccfbvc170120.fits          2           0.006  (484.9905, 435.0559)
# 8   ccfbvc170120.fits          2           0.006  (266.2868, 418.8551)
# 9   ccfbvc170121.fits          2           0.006  (178.0998, 506.4224)
# 10  ccfbvc170121.fits          2           0.009  (443.4051, 132.5788)
# 11  ccfbvc310078.fits          2           0.006   (178.0553, 506.567)
# ...

# %%
df.iloc[5], df.iloc[3], df.iloc[4]
# Out:
# (image                                            ccfbvc170119.fits
#  num_iters                                                        2
#  execution_time                                               0.008
#  star_coord                                    (515.4571, 110.0911)
#  rel_klds             [0.08026263792816644, 2.5965690073190985e-15]
#  rel_recon_errors           [0.636093137014073, 0.6360931370140935]
#  flux_before                                              78685.954
#  flux_after                                               78438.959
#  bkg_before                                               124.84569
#  bkg_after                                                 1.657682
#  l1_centroid_err                                              1.221
#  before_ecc                                                0.047768
#  after_ecc                                                 0.175844
#  before_fwhm (pix)                                           12.706
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df['flux_before'], alpha=0.5)
plt.plot(df['flux_after'], alpha=0.5)
